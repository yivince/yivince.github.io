# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Collecting getorg
#   Downloading getorg-0.3.1-py2.py3-none-any.whl (39 kB)
# Collecting geopy
#   Using cached geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting pygithub
#   Downloading PyGithub-1.54.1-py3-none-any.whl (289 kB)
# Collecting geographiclib<2,>=1.49
#   Using cached geographiclib-1.50-py3-none-any.whl (38 kB)
# Requirement already satisfied, skipping upgrade: six>=1.7.0 in d:\programdata\anaconda3\lib\site-packages (from retrying->getorg) (1.14.0)
# Requirement already satisfied, skipping upgrade: requests>=2.14.0 in d:\programdata\anaconda3\lib\site-packages (from pygithub->getorg) (2.22.0)
# Collecting pyjwt<2.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting deprecated
#   Downloading Deprecated-1.2.12-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\programdata\anaconda3\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (1.25.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in d:\programdata\anaconda3\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in d:\programdata\anaconda3\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in d:\programdata\anaconda3\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (2.8)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in d:\programdata\anaconda3\lib\site-packages (from deprecated->pygithub->getorg) (1.11.2)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11435 sha256=36fad27c92ceaf9365035d562c12caec1e80a6749d12321b1f4879c42623d75e
#   Stored in directory: c:\users\administrator\appdata\local\pip\cache\wheels\f9\8d\8d\f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# Installing collected packages: geographiclib, geopy, retrying, pyjwt, deprecated, pygithub, getorg
# Successfully installed deprecated-1.2.12 geographiclib-1.50 geopy-2.1.0 getorg-0.3.1 pygithub-1.54.1 pyjwt-1.7.1 retrying-1.3.3
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-3-cd980ae579e7> in <module>
# ----> 1 geocoder = Nominatim()
#       2 location_dict = {}
#       3 location = ""
#       4 permalink = ""
#       5 title = ""
#
# D:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\nominatim.py in __init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     112                 'overriding the default `user_agent`: '
#     113                 '`geopy.geocoders.options.default_user_agent = "my-application"`.'
# --> 114                 % self.headers['User-Agent']
#     115             )
#     116
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "geopy/2.1.0" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
